# %%
import pandas as pd
import numpy as np
import requests
from dotenv import load_dotenv
import os
import requests
import time
load_dotenv()

# %%
GH_PERSONAL_ACCESS_TOKEN = os.getenv("GH_PERSONAL_ACCESS_TOKEN")

# %%
spam_issues_df = pd.read_pickle("../data/spam-issues-1717917295.9858763.pkl")

# %% [markdown]
# Fetch spam issues

# %%
headers = {f"Authorization": "Bearer {GH_PERSONAL_ACCESS_TOKEN}"}
owner = "keybase"
repo = "client"
state = "open"
page = 1
per_page = 26
response = requests.get(f"https://api.github.com/repos/{owner}/{repo}/issues?state={state}&page={page}&per_page={per_page}")

json = response.json()
print(json)
# Out:
# [{'url': 'https://api.github.com/repos/keybase/client/issues/27039', 'repository_url': 'https://api.github.com/repos/keybase/client', 'labels_url': 'https://api.github.com/repos/keybase/client/issues/27039/labels{/name}', 'comments_url': 'https://api.github.com/repos/keybase/client/issues/27039/comments', 'events_url': 'https://api.github.com/repos/keybase/client/issues/27039/events', 'html_url': 'https://github.com/keybase/client/issues/27039', 'id': 2345069508, 'node_id': 'I_kwDOAbwErc6LxuvE', 'number': 27039, 'title': 'TRUSTED CRYPTO CURRENCY RECOVERY EXPERT//FOLKWIN EXPERT RECOVERY.', 'user': {'login': 'FordHazard', 'id': 172087345, 'node_id': 'U_kgDOCkHYMQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/172087345?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/FordHazard', 'html_url': 'https://github.com/FordHazard', 'followers_url': 'https://api.github.com/users/FordHazard/followers', 'following_url': 'https://api.github.com/users/FordHazard/following{/other_user}', 'gists_url': 'https://api.github.com/users/FordHazard/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/FordHazard/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/FordHazard/subscriptions', 'organizations_url': 'https://api.github.com/users/FordHazard/orgs', 'repos_url': 'https://api.github.com/users/FordHazard/repos', 'events_url': 'https://api.github.com/users/FordHazard/events{/privacy}', 'received_events_url': 'https://api.github.com/users/FordHazard/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-06-11T00:15:47Z', 'updated_at': '2024-06-11T00:15:47Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'body': "\r\nThe sting of betrayal is a cruel mistress. It can leave you reeling, questioning your judgment, and feeling utterly vulnerable. \xa0This is precisely how I felt when I fell victim to a binary trading scam. \xa0The promise of lucrative returns, and a comfortable retirement, \xa0all those dreams I had meticulously built for decades crumbled under the weight of deceit. I had entrusted my hard-earned savings to a company that promised the moon, only to find myself in a desolate wasteland of broken promises and financial ruin. The company, a viper disguised in a suit of legitimacy, \xa0vanished into thin air, leaving me with nothing but shattered dreams and a hefty debt. \xa0The betrayal cut deep, \xa0a wound that festered with anger and despair. I sought solace in the digital world, \xa0hoping to find a path to recovery. I immersed myself in forums and online communities, searching for a solution, a glimmer of hope in the abyss of my despair. My research led me to countless tales of woe, \xa0stories that echoed my pain. \xa0But amidst the despair, \xa0a beacon of hope emerged – Folkwin Expert Recovery. They were a lifeline, a beacon of light in the darkness. They understood my pain, my anguish, and my desperation. Their approach was compassionate and understanding, a stark contrast to the cold indifference I had encountered from the scammers. Folkwin Expert Recovery didn't sugarcoat the process. \xa0They laid out the challenges, the complexities of recovering funds from fraudulent online ventures. \xa0But their expertise, their unwavering determination, \xa0and their transparency instilled in me a sense of trust that I had lost long ago. I placed my faith in their hands, clinging to the hope they offered. The wait was agonizing, each passing day stretching into an eternity. \xa0But then, \xa0the email arrived – a beacon of light in my digital inbox. Folkwin Expert Recovery had succeeded in recovering a significant portion of my stolen funds. It wasn't a complete victory, but it was a resounding triumph against the forces of deceit. My experience has left me with a profound respect for Folkwin Expert Recovery. They are ...

# %%
normalised = pd.json_normalize(json)
normalised_filtered = normalised.filter(items=["id", "url", "user.login", "title", "body", "labels"])
normalised_filtered.head()
# Out:
#            id                                                url  \
# 0  2345069508  https://api.github.com/repos/keybase/client/is...
# 1  2344960415  https://api.github.com/repos/keybase/client/is...
# 2  2344840392  https://api.github.com/repos/keybase/client/is...
# 3  2344835423  https://api.github.com/repos/keybase/client/is...
# 4  2344807034  https://api.github.com/repos/keybase/client/is...
#
#        user.login                                              title  \
# 0      FordHazard  TRUSTED CRYPTO CURRENCY RECOVERY EXPERT//FOLKW...
# 1   CynthiaCreech  HIRE THE MOST POPULAR BITCOIN RECOVERY EXPERT ...
# 2  helenhoward998  HIRE FAST SWIFT CYBER SERVICES TO RECOVER YOUR...
# 3  helenhoward998  HIRE FAST SWIFT CYBER SERVICES TO RECOVER YOUR...
# 4     sofiacaleb7  WIZARD WEB RECOVERY SCAMMED CRYPTO ASSET TRACI...
#
#                                                 body labels
# 0  \r\nThe sting of betrayal is a cruel mistress....     []
# 1  Website info: www.adwarerecoveryspecialist.exp...     []
# 2  I, David , a businessman from Colorado Springs...     []
# 3  I, David , a businessman from Colorado Springs...     []
# 4  The promise of quick riches and financial inde...     []

# %% [markdown]
# Splice data if necessary

# %%
# normalised_filtered=normalised_filtered[:-1]

# %%
# normalised_filtered.head()
normalised_filtered.tail()
# Out:
#             id                                                url  \
# 21  2341980286  https://api.github.com/repos/keybase/client/is...
# 22  2341962737  https://api.github.com/repos/keybase/client/is...
# 23  2341858495  https://api.github.com/repos/keybase/client/is...
# 24  2341808839  https://api.github.com/repos/keybase/client/is...
# 25  2341703642  https://api.github.com/repos/keybase/client/is...
#
#         user.login                                              title  \
# 21    georgiadixon  RETRIEVE YOUR SCAMMED CRYPTO ASSETS,BTCOIN AND...
# 22    georgiadixon  RETRIEVE YOUR SCAMMED CRYPTO ASSETS,BTCOIN AND...
# 23      Gasperstin  REVIEW OF THE BEST BITCOIN RECOVERY TEAM - GRA...
# 24    georgiadixon  RETRIEVE YOUR SCAMMED CRYPTO ASSETS,BTCOIN AND...
# 25  JimOllenberger  BEST BITCOIN COMPANY RECOVERY HIRE ADWARE RECO...
#
#                                                  body labels
# 21  The pain of losing a substantial amount of har...     []
# 22  The pain of losing a substantial amount of har...     []
# 23  I can't help myself but give a glowing review ...     []
# 24  The pain of losing a substantial amount of har...     []
# 25  Website info: www.adwarerecoveryspecialist.exp...     []

# %%
spam_issues_df = pd.concat([spam_issues_df, normalised_filtered])

# %%
spam_issues_df

# %%
spam_issues_df.to_pickle(f"../data/spam-issues-{time.time()}.pkl")
